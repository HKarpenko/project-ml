# %%
import pandas as pd

old_df = pd.read_csv('data.csv')
old_df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
new_df = pd.read_csv('new_data.csv', index_col="ID")
new_df.pop("release_date")
new_df
# Out:
#         valence  year  acousticness  danceability  duration_ms  energy  \
# ID
# 0        0.0594  1921       0.98200         0.279       831667   0.211
# 1        0.9630  1921       0.73200         0.819       180533   0.341
# 2        0.0394  1921       0.96100         0.328       500062   0.166
# 3        0.1650  1921       0.96700         0.275       210000   0.309
# 4        0.2530  1921       0.95700         0.418       166693   0.193
# ...         ...   ...           ...           ...          ...     ...
# 170648   0.6080  2020       0.08460         0.786       301714   0.808
# 170649   0.7340  2020       0.20600         0.717       150654   0.753
# 170650   0.6370  2020       0.10100         0.634       211280   0.858
# 170651   0.1950  2020       0.00998         0.671       337147   0.623
# 170652   0.6420  2020       0.13200         0.856       189507   0.721
#
#         explicit  instrumentalness  key  liveness  loudness  mode  popularity  \
# ID
# ...

# %%
years = new_df["year"].unique()
years
# Out:
# array([1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#        1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
#        1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#        1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#        1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020])

# %%
decade = 20
tmp_df = pd.DataFrame()
for year in years:
    if year % 10 != 0: 
        tmp_df = tmp_df.append(new_df.loc[new_df["year"] == year])
    else:
        if decade == 0:
            tmp_df.to_csv(f"data_by_decade/data_from_0{decade}s.csv")
        else:
            tmp_df.to_csv(f"data_by_decade/data_from_{decade}s.csv")
        tmp_df = pd.DataFrame()
        decade += 10
        if decade >= 100:
            decade = 0

# %%
df1 = pd.read_csv("data_by_decade/data_from_00s.csv")
df1
# Out:
#            ID  valence  year  acousticness  danceability  duration_ms  energy  \
# 0       15806    0.903  2001      0.037100         0.643       165853   0.849
# 1       15807    0.499  2001      0.154000         0.468       259933   0.640
# 2       15808    0.692  2001      0.000481         0.589       199907   0.890
# 3       15809    0.661  2001      0.007190         0.654       200307   0.810
# 4       15810    0.286  2001      0.000278         0.419       210240   0.934
# ...       ...      ...   ...           ...           ...          ...     ...
# 17685  168448    0.134  2009      0.933000         0.291       213253   0.196
# 17686  168449    0.405  2009      0.115000         0.743       271440   0.669
# 17687  168450    0.410  2009      0.246000         0.675       242467   0.827
# 17688  168451    0.478  2009      0.042400         0.796       211093   0.712
# 17689  168452    0.275  2009      0.616000         0.486       211453   0.506
#
# ...

# %%
df2 = pd.read_csv("data_by_decade/data_from_10s.csv")
df2
# Out:
#            ID  valence  year  acousticness  danceability  duration_ms  energy  \
# 0       17806    0.371  2011      0.008470         0.560       218013   0.936
# 1       17807    0.965  2011      0.145000         0.733       239600   0.710
# 2       17808    0.216  2011      0.053100         0.831       235320   0.427
# 3       17809    0.285  2011      0.892000         0.559       285040   0.330
# 4       17810    0.854  2011      0.498000         0.657       182947   0.560
# ...       ...      ...   ...           ...           ...          ...     ...
# 17753  170448    0.704  2019      0.226000         0.757       159547   0.688
# 17754  170449    0.223  2019      0.001210         0.449       247613   0.825
# 17755  170450    0.233  2019      0.016700         0.616       203555   0.469
# 17756  170451    0.494  2019      0.000755         0.766       196875   0.649
# 17757  170452    0.305  2019      0.233000         0.780       132115   0.453
#
# ...

# %%
df3 = pd.read_csv("data_by_decade/data_from_40s.csv")
df3
# Out:
#            ID  valence  year  acousticness  danceability  duration_ms  energy  \
# 0        3806    0.656  1941         0.945         0.794       190573   0.174
# 1        3807    0.465  1941         0.931         0.727       197440   0.236
# 2        3808    0.893  1941         0.911         0.733       180427   0.431
# 3        3809    0.316  1941         0.976         0.441       203667   0.123
# 4        3810    0.765  1941         0.569         0.629       177960   0.322
# ...       ...      ...   ...           ...           ...          ...     ...
# 13373  156548    0.534  1949         0.925         0.752       187733   0.194
# 13374  156549    0.178  1949         0.917         0.600        33653   0.453
# 13375  156550    0.480  1949         0.873         0.720       185200   0.793
# 13376  156551    0.292  1949         0.961         0.412       141227   0.211
# 13377  156552    0.764  1949         0.984         0.726       204103   0.297
#
# ...
